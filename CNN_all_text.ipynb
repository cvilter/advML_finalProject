# %% [markdown]
# CNN model using sectioned data set, complete data set used, randomized embeddings

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

import torch
from torch.utils.data import DataLoader
from torch import nn
import torch.nn.functional as F
from torch.utils.data.dataset import random_split

import torchtext
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import Vectors, build_vocab_from_iterator
from torchtext.vocab import GloVe

from torchmetrics.classification import BinaryRecall
from torchmetrics.classification import BinaryPrecision

import math
from string import digits

# %%
df = pd.read_csv("data/ML_text_data.csv")

# %%
def clean_text(text):
    '''
    Function the removes frequent phrases and numbers from text that
    are not relevant to text classifcation
    '''
    text = text.replace("\n", " ")
    text = text.replace("New Text Underlined", "")
    text = text.replace("[DELETED TEXT BRACKETED]", "")
    text = text.replace("HOUSE BILL", "")
    text = text.replace("SENATE BILL", "")
    text = re.sub(" {2,}", " ", text)
    remove_digits = str.maketrans('', '', digits)
    text = text.translate(remove_digits)

    return text

# %%
len(df)
# Out:
# 2660

# %% [markdown]
# Convert data into list of tuples

# %%
data = zip(df['discriminatory'], df['text'])

# %%
data_list = [(label, tokens) for (label, tokens) in data]

# %% [markdown]
# Randomly split data into training, validation, test prior to dividing bills into 500 word sections

# %%
# Prep for data split
len_train = int(len(data_list) * .8)
len_valid = int((len(data_list) - len_train)/2)
len_test = len(data_list) - len_train - len_valid
print(len_train, "train", len_valid, "validation", len_test, "testing")
# Out:
# 2128 train 266 validation 266 testing

# %%
train_data, valid_data, test_data = random_split(
    data_list, [len_train, len_valid, len_test])

# %%
tokenizer = get_tokenizer('basic_english')

# %% [markdown]
# Divide each bill into 500 word sections, maintaining the label for each section

# %%
#standardize bill length - split and pad
def standardize_text(data_list):
    '''
    function takes in data and splits bill into 500 word sections
    pads any bill that are less than 500 words
    returns list of tokens and label for each bill section
    '''
    data = []
    for i, (label, text) in enumerate(data_list):
        text = clean_text(text)
        all_tokens = tokenizer(text)
        if len(all_tokens) > 500:
            num_div = math.trunc(len(all_tokens)/500)
            for i in range(num_div):
                tokens = all_tokens[i*500:(i+1)*500]
                data.append((label, tokens))
            end_tokens = all_tokens[num_div*500:]
            pad_len = 500 - len(end_tokens)
            padding = ['<unk>'] * pad_len
            end_tokens = end_tokens + padding
            data.append((label, end_tokens))
        else:
            pad_len = 500 - len(all_tokens)
            padding = ['<unk>'] * pad_len
            tokens = all_tokens + padding
            data.append((label, tokens))

    return data

# %%
train_data = standardize_text(train_data)
valid_data = standardize_text(valid_data)
test_data = standardize_text(test_data)

# %%
print(f'lenths train_data: {len(train_data)}, valid_data: {len(valid_data)}, test_data: {len(test_data)}')
# Out:
# lenths train_data: 14586, valid_data: 1531, test_data: 1469

# %% [markdown]
# Build vocabulary

# %%
def yield_tokens(data_iter):
    for _, text in data_iter:
        text = clean_text(text)
        text = tokenizer(text)
        yield text

# %%
vocab = build_vocab_from_iterator(
    yield_tokens(data_list), specials=["<unk>"], min_freq=100)

# %%
vocab.set_default_index(vocab["<unk>"])

# %%
# Checking the result
print(len(vocab))
print(vocab.lookup_token(0))
print(vocab.lookup_token(15))
print(vocab["bill"])
print(vocab["gender"])
print(vocab["pronoun"])
print(vocab["transgender"])
# Out:
# 3985
# <unk>
# is
# 137
# 181
# 2495
# 3617

# %% [markdown]
# Create collate function for data builder

# %%
def collate_fn(batch):
    labels = torch.tensor([x[0] for x in batch])
    text = [x[1] for x in batch]
    word_idxs = []
    for sequence in text:
        window_idxs = [vocab[word] for word in sequence]
        word_idxs.append(window_idxs)
    word_idxs = torch.tensor(word_idxs)
    return labels, word_idxs

# %% [markdown]
# Build model

# %%
class CNNClassifier(nn.ModuleList):

   def __init__(self,
                 embedding_dim,
                 sequence_len,
                 vocab_len, 
                 out_size,
                 stride):       
      super(CNNClassifier, self).__init__()

      self.embedding_size = embedding_dim
      self.seq_len = sequence_len
      self.vocab_len = vocab_len
  
      # Dropout definition
      self.dropout = nn.Dropout(0.25)
      
      # CNN parameters definition
      # Kernel sizes
      self.kernel_1 = 2
      self.kernel_2 = 3
      self.kernel_3 = 4
      self.kernel_4 = 5
      
      # Output size for each convolution
      self.out_size = out_size
      # Number of strides for each convolution
      self.stride = stride
      
      # Embedding layer definition
      self.embedding = nn.Embedding(self.vocab_len + 1, self.embedding_size, padding_idx=0)
      
      # Convolution layers definition
      self.conv_1 = nn.Conv1d(self.seq_len, self.out_size, self.kernel_1, self.stride)
      self.conv_2 = nn.Conv1d(self.seq_len, self.out_size, self.kernel_2, self.stride)
      self.conv_3 = nn.Conv1d(self.seq_len, self.out_size, self.kernel_3, self.stride)
      self.conv_4 = nn.Conv1d(self.seq_len, self.out_size, self.kernel_4, self.stride)
      
      # Max pooling layers definition
      self.pool_1 = nn.MaxPool1d(self.kernel_1, self.stride)
      self.pool_2 = nn.MaxPool1d(self.kernel_2, self.stride)
      self.pool_3 = nn.MaxPool1d(self.kernel_3, self.stride)
      self.pool_4 = nn.MaxPool1d(self.kernel_4, self.stride)
      
      # Fully connected layer definition
      self.fc = nn.Linear(self.in_features_fc(), 1)

   def in_features_fc(self):
      '''Calculates the number of output features after Convolution + Max pooling
         
      Convolved_Features = ((embedding_size + (2 * padding) - dilation * (kernel - 1) - 1) / stride) + 1
      Pooled_Features = ((embedding_size + (2 * padding) - dilation * (kernel - 1) - 1) / stride) + 1
      
      source: https://pytorch.org/docs/stable/generated/torch.nn.Conv1d.html
      '''
      # Calcualte size of convolved/pooled features for convolution_1/max_pooling_1 features
      out_conv_1 = ((self.embedding_size - 1 * (self.kernel_1 - 1) - 1) / self.stride) + 1
      out_conv_1 = math.floor(out_conv_1)
      out_pool_1 = ((out_conv_1 - 1 * (self.kernel_1 - 1) - 1) / self.stride) + 1
      out_pool_1 = math.floor(out_pool_1)
      
      # Calcualte size of convolved/pooled features for convolution_2/max_pooling_2 features
      out_conv_2 = ((self.embedding_size - 1 * (self.kernel_2 - 1) - 1) / self.stride) + 1
      out_conv_2 = math.floor(out_conv_2)
      out_pool_2 = ((out_conv_2 - 1 * (self.kernel_2 - 1) - 1) / self.stride) + 1
      out_pool_2 = math.floor(out_pool_2)
      
      # Calcualte size of convolved/pooled features for convolution_3/max_pooling_3 features
      out_conv_3 = ((self.embedding_size - 1 * (self.kernel_3 - 1) - 1) / self.stride) + 1
      out_conv_3 = math.floor(out_conv_3)
      out_pool_3 = ((out_conv_3 - 1 * (self.kernel_3 - 1) - 1) / self.stride) + 1
      out_pool_3 = math.floor(out_pool_3)
      
      # Calcualte size of convolved/pooled features for convolution_4/max_pooling_4 features
      out_conv_4 = ((self.embedding_size - 1 * (self.kernel_4 - 1) - 1) / self.stride) + 1
      out_conv_4 = math.floor(out_conv_4)
      out_pool_4 = ((out_conv_4 - 1 * (self.kernel_4 - 1) - 1) / self.stride) + 1
      out_pool_4 = math.floor(out_pool_4)
      
      # Returns "flattened" vector (input for fully connected layer)
      return (out_pool_1 + out_pool_2 + out_pool_3 + out_pool_4) * self.out_size
   
   def forward(self, x):

      # Sequence of tokes is filterd through an embedding layer
      x = self.embedding(x)
      
      # Convolution layer 1 is applied
      x1 = self.conv_1(x)
      x1 = torch.relu(x1)
      x1 = self.pool_1(x1)
      
      # Convolution layer 2 is applied
      x2 = self.conv_2(x)
      x2 = torch.relu((x2))
      x2 = self.pool_2(x2)
   
      # Convolution layer 3 is applied
      x3 = self.conv_3(x)
      x3 = torch.relu(x3)
      x3 = self.pool_3(x3)
      
      # Convolution layer 4 is applied
      x4 = self.conv_4(x)
      x4 = torch.relu(x4)
      x4 = self.pool_4(x4)
      
      # The output of each convolutional layer is concatenated into a unique vector
      union = torch.cat((x1, x2, x3, x4), 2)
      union = union.reshape(union.size(0), -1)

      # The "flattened" vector is passed through a fully connected layer
      out = self.fc(union)
      # Dropout is applied		
      out = self.dropout(out)
      # Activation function is applied
      out = torch.sigmoid(out)
      
      return out.squeeze()

# %%
model = CNNClassifier(embedding_dim = 64,
                 sequence_len = 500,
                 vocab_len = len(vocab), 
                 out_size = 32,
                 stride = 2)

# %% [markdown]
# Create functions to train model and evaluate performance

# %%
loss_function = nn.CrossEntropyLoss()

def train_an_epoch(dataloader, optimizer):
    model.train() 
    log_interval = 50

    for idx, (label, text) in enumerate(dataloader):
        model.zero_grad()
        log_probs = model(text)
        loss = loss_function(log_probs, label.type('torch.FloatTensor'))
        loss.backward()
        optimizer.step()
        if idx % log_interval == 0 and idx > 0:
            print(f'At iteration {idx} the loss is {loss:.3f}.')

# %%
def get_accuracy(dataloader):
    model.eval()
    with torch.no_grad():    
        total_acc, total_count = 0, 0
        all_recall = []
        all_precision = []
        recall_metric = BinaryRecall()
        precision_metric = BinaryPrecision()
        for idx, (label, word_idxs) in enumerate(dataloader):
            log_probs = model(word_idxs)
            total_acc += (log_probs.round() == label).sum().item()
            total_count += label.size(0)
            recall = recall_metric(log_probs, label)
            precision = precision_metric(log_probs, label)
            all_recall.append(recall)
            all_precision.append(precision)
    accuracy = total_acc/total_count

    return accuracy, np.mean(all_recall), np.mean(all_precision)

# %% [markdown]
# Create data loaders

# %%
BATCH_SIZE = 16

train_dataloader = DataLoader(train_data, batch_size=BATCH_SIZE,
                              shuffle=True, 
                              collate_fn=collate_fn)
valid_dataloader = DataLoader(valid_data, batch_size=BATCH_SIZE,
                              shuffle=False, 
                              collate_fn=collate_fn)
test_dataloader = DataLoader(test_data, batch_size=BATCH_SIZE,
                             shuffle=False, 
                             collate_fn=collate_fn)

# %% [markdown]
# Execute model training

# %%
import time
import matplotlib.pyplot as plt
# %matplotlib inline

EPOCHS = 30 # epoch
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

accuracies=[]
recalls=[]
precisions=[]
for epoch in range(1, EPOCHS + 1):
    epoch_start_time = time.time()
    train_an_epoch(train_dataloader, optimizer)
    accuracy, recall, precision = get_accuracy(valid_dataloader)
    accuracies.append(accuracy)
    recalls.append(recall)
    precisions.append(precision)
    time_taken = time.time() - epoch_start_time
    print(f'Epoch: {epoch}, time taken: {time_taken:.1f}s, validation accuracy: {accuracy:.3f}, recall: {recall}, precision: {precision}.')
    
plt.plot(range(1, EPOCHS+1), accuracies)

accuracy, recall, precision = get_accuracy(test_dataloader)
print(f'The estimated test accuracy is {accuracy:.3f}, recall {recall}, precision {precision}.')
# Out:
# At iteration 50 the loss is 21.898.
# At iteration 100 the loss is 19.016.
# At iteration 150 the loss is 13.294.
# At iteration 200 the loss is 24.129.
# At iteration 250 the loss is 16.123.
# At iteration 300 the loss is 21.734.
# At iteration 350 the loss is 16.555.
# At iteration 400 the loss is 18.510.
# At iteration 450 the loss is 21.627.
# At iteration 500 the loss is 36.144.
# At iteration 550 the loss is 19.069.
# At iteration 600 the loss is 25.201.
# At iteration 650 the loss is 19.334.
# At iteration 700 the loss is 10.422.
# At iteration 750 the loss is 18.889.
# At iteration 800 the loss is 21.407.
# At iteration 850 the loss is 18.275.
# At iteration 900 the loss is 13.177.
# Epoch: 1, time taken: 29.6s, validation accuracy: 0.767, recall: 0.1528850942850113, precision: 0.1909722238779068.
# At iteration 50 the loss is 24.372.
# At iteration 100 the loss is 18.855.
# At iteration 150 the loss is 18.988.
# At iteration 200 the loss is 22.322.
# At iteration 250 the loss is 18.592.
# At iteration 300 the loss is 21.016.
# At iteration 350 the loss is 12.578.
# At iteration 400 the loss is 15.434.
# At iteration 450 the loss is 19.510.
# At iteration 500 the loss is 15.432.
# At iteration 550 the loss is 12.895.
# At iteration 600 the loss is 10.463.
# At iteration 650 the loss is 23.721.
# At iteration 700 the loss is 10.056.
# At iteration 750 the loss is 12.470.
# At iteration 800 the loss is 23.962.
# At iteration 850 the loss is 21.727.
# At iteration 900 the loss is 17.883.
# Epoch: 2, time taken: 29.4s, validation accuracy: 0.778, recall: 0.295381635427475, precision: 0.4600198268890381.
# At iteration 50 the loss is 6.797.
# At iteration 100 the loss is 15.425.
# At iteration 150 the loss is 21.054.
# At iteration 200 the loss is 23.717.
# At iteration 250 the loss is 18.172.
# At iteration 300 the loss is 26.159.
# At iteration 350 the loss is 21.018.
# At iteration 400 the loss is 23.742.
# At iteration 450 the loss is 15.171.
# At iteration 500 the loss is 12.300.
# At iteration 550 the loss is 26.558.
# At iteration 600 the loss is 32.409.
# At iteration 650 the loss is 14.743.
# At iteration 700 the loss is 12.399.
# At iteration 750 the loss is 14.879.
# At iteration 800 the loss is 9.675.
# At iteration 850 the loss is 12.631.
# At iteration 900 the loss is 15.293.
# Epoch: 3, time taken: 28.0s, validation accuracy: 0.796, recall: 0.3866804540157318, precision: 0.4986442029476166.
# At iteration 50 the loss is 12.193.
# At iteration 100 the loss is 20.176.
# At iteration 150 the loss is 15.004.
# At iteration 200 the loss is 18.147.
# At iteration 250 the loss is 20.161.
# At iteration 300 the loss is 8.859.
# At iteration 350 the loss is 17.185.
# At iteration 400 the loss is 12.557.
# At iteration 450 the loss is 13.055.
# At iteration 500 the loss is 12.600.
# At iteration 550 the loss is 22.836.
# At iteration 600 the loss is 20.997.
# At iteration 650 the loss is 12.127.
# At iteration 700 the loss is 7.210.
# At iteration 750 the loss is 29.295.
# At iteration 800 the loss is 14.713.
# At iteration 850 the loss is 14.696.
# At iteration 900 the loss is 12.113.
# Epoch: 4, time taken: 29.2s, validation accuracy: 0.785, recall: 0.44216665625572205, precision: 0.4895213544368744.
# At iteration 50 the loss is 14.876.
# At iteration 100 the loss is 14.792.
# At iteration 150 the loss is 12.225.
# At iteration 200 the loss is 14.506.
# At iteration 250 the loss is 19.844.
# At iteration 300 the loss is 20.606.
# At iteration 350 the loss is 14.545.
# At iteration 400 the loss is 14.708.
# At iteration 450 the loss is 14.325.
# At iteration 500 the loss is 12.077.
# At iteration 550 the loss is 22.997.
# At iteration 600 the loss is 11.860.
# At iteration 650 the loss is 19.713.
# At iteration 700 the loss is 14.191.
# At iteration 750 the loss is 20.235.
# At iteration 800 the loss is 17.189.
# At iteration 850 the loss is 12.983.
# At iteration 900 the loss is 26.109.
# Epoch: 5, time taken: 28.8s, validation accuracy: 0.792, recall: 0.383815199136734, precision: 0.48167291283607483.
# At iteration 50 the loss is 22.924.
# At iteration 100 the loss is 9.118.
# At iteration 150 the loss is 16.980.
# At iteration 200 the loss is 20.173.
# At iteration 250 the loss is 12.204.
# At iteration 300 the loss is 19.988.
# At iteration 350 the loss is 19.451.
# At iteration 400 the loss is 11.851.
# At iteration 450 the loss is 14.562.
# At iteration 500 the loss is 14.262.
# At iteration 550 the loss is 17.318.
# At iteration 600 the loss is 14.929.
# At iteration 650 the loss is 20.004.
# At iteration 700 the loss is 23.202.
# At iteration 750 the loss is 22.702.
# At iteration 800 the loss is 17.831.
# At iteration 850 the loss is 9.449.
# At iteration 900 the loss is 17.953.
# Epoch: 6, time taken: 29.2s, validation accuracy: 0.799, recall: 0.3856525719165802, precision: 0.4698082208633423.
# At iteration 50 the loss is 20.277.
# At iteration 100 the loss is 4.756.
# At iteration 150 the loss is 19.572.
# At iteration 200 the loss is 20.462.
# At iteration 250 the loss is 20.097.
# At iteration 300 the loss is 23.381.
# At iteration 350 the loss is 11.589.
# At iteration 400 the loss is 16.841.
# At iteration 450 the loss is 15.302.
# At iteration 500 the loss is 17.571.
# At iteration 550 the loss is 9.492.
# At iteration 600 the loss is 11.846.
# At iteration 650 the loss is 19.783.
# At iteration 700 the loss is 14.701.
# At iteration 750 the loss is 11.819.
# At iteration 800 the loss is 28.641.
# At iteration 850 the loss is 14.370.
# At iteration 900 the loss is 23.002.
# Epoch: 7, time taken: 28.4s, validation accuracy: 0.794, recall: 0.41477417945861816, precision: 0.49097371101379395.
# At iteration 50 the loss is 12.012.
# At iteration 100 the loss is 19.970.
# At iteration 150 the loss is 26.003.
# At iteration 200 the loss is 17.900.
# At iteration 250 the loss is 9.563.
# At iteration 300 the loss is 12.233.
# At iteration 350 the loss is 7.285.
# At iteration 400 the loss is 18.203.
# At iteration 450 the loss is 17.223.
# At iteration 500 the loss is 15.101.
# At iteration 550 the loss is 16.720.
# At iteration 600 the loss is 14.614.
# At iteration 650 the loss is 20.242.
# At iteration 700 the loss is 22.678.
# At iteration 750 the loss is 9.278.
# At iteration 800 the loss is 16.877.
# At iteration 850 the loss is 20.234.
# At iteration 900 the loss is 18.504.
# Epoch: 8, time taken: 28.9s, validation accuracy: 0.807, recall: 0.3999411165714264, precision: 0.48179563879966736.
# At iteration 50 the loss is 23.117.
# At iteration 100 the loss is 11.721.
# At iteration 150 the loss is 6.630.
# At iteration 200 the loss is 19.570.
# At iteration 250 the loss is 9.531.
# At iteration 300 the loss is 4.660.
# At iteration 350 the loss is 22.998.
# At iteration 400 the loss is 23.031.
# At iteration 450 the loss is 14.375.
# At iteration 500 the loss is 19.609.
# At iteration 550 the loss is 17.745.
# At iteration 600 the loss is 14.603.
# At iteration 650 the loss is 12.178.
# At iteration 700 the loss is 28.641.
# At iteration 750 the loss is 11.643.
# At iteration 800 the loss is 16.575.
# At iteration 850 the loss is 14.283.
# At iteration 900 the loss is 17.899.
# Epoch: 9, time taken: 28.8s, validation accuracy: 0.774, recall: 0.46986499428749084, precision: 0.47597554326057434.
# At iteration 50 the loss is 20.198.
# At iteration 100 the loss is 19.948.
# At iteration 150 the loss is 11.155.
# At iteration 200 the loss is 22.636.
# At iteration 250 the loss is 17.392.
# At iteration 300 the loss is 17.399.
# At iteration 350 the loss is 19.736.
# At iteration 400 the loss is 20.630.
# At iteration 450 the loss is 14.297.
# At iteration 500 the loss is 13.478.
# At iteration 550 the loss is 19.938.
# At iteration 600 the loss is 19.583.
# At iteration 650 the loss is 17.199.
# At iteration 700 the loss is 17.460.
# At iteration 750 the loss is 20.780.
# At iteration 800 the loss is 17.002.
# At iteration 850 the loss is 14.639.
# At iteration 900 the loss is 22.807.
# Epoch: 10, time taken: 28.8s, validation accuracy: 0.805, recall: 0.39190801978111267, precision: 0.49846354126930237.
# At iteration 50 the loss is 17.094.
# At iteration 100 the loss is 14.594.
# At iteration 150 the loss is 14.700.
# At iteration 200 the loss is 6.849.
# At iteration 250 the loss is 14.514.
# At iteration 300 the loss is 17.569.
# At iteration 350 the loss is 8.748.
# At iteration 400 the loss is 23.072.
# At iteration 450 the loss is 20.178.
# At iteration 500 the loss is 19.931.
# At iteration 550 the loss is 12.007.
# At iteration 600 the loss is 23.305.
# At iteration 650 the loss is 19.533.
# At iteration 700 the loss is 14.070.
# At iteration 750 the loss is 17.098.
# At iteration 800 the loss is 6.449.
# At iteration 850 the loss is 14.362.
# At iteration 900 the loss is 17.483.
# Epoch: 11, time taken: 28.5s, validation accuracy: 0.788, recall: 0.4728221893310547, precision: 0.48366060853004456.
# At iteration 50 the loss is 19.714.
# At iteration 100 the loss is 19.562.
# At iteration 150 the loss is 9.392.
# At iteration 200 the loss is 12.113.
# At iteration 250 the loss is 11.145.
# At iteration 300 the loss is 14.175.
# At iteration 350 the loss is 22.579.
# At iteration 400 the loss is 11.173.
# At iteration 450 the loss is 14.739.
# At iteration 500 the loss is 14.748.
# At iteration 550 the loss is 17.438.
# At iteration 600 the loss is 13.791.
# At iteration 650 the loss is 17.131.
# At iteration 700 the loss is 9.397.
# At iteration 750 the loss is 11.938.
# At iteration 800 the loss is 8.850.
# At iteration 850 the loss is 9.408.
# At iteration 900 the loss is 14.179.
# Epoch: 12, time taken: 28.0s, validation accuracy: 0.806, recall: 0.3940505087375641, precision: 0.501069962978363.
# At iteration 50 the loss is 19.935.
# At iteration 100 the loss is 22.980.
# At iteration 150 the loss is 17.600.
# At iteration 200 the loss is 12.175.
# At iteration 250 the loss is 17.126.
# At iteration 300 the loss is 22.604.
# At iteration 350 the loss is 19.932.
# At iteration 400 the loss is 19.955.
# At iteration 450 the loss is 22.939.
# At iteration 500 the loss is 23.113.
# At iteration 550 the loss is 8.882.
# At iteration 600 the loss is 17.700.
# At iteration 650 the loss is 17.449.
# At iteration 700 the loss is 17.055.
# At iteration 750 the loss is 17.556.
# At iteration 800 the loss is 22.731.
# At iteration 850 the loss is 6.354.
# At iteration 900 the loss is 19.882.
# Epoch: 13, time taken: 28.7s, validation accuracy: 0.815, recall: 0.39797505736351013, precision: 0.5124112963676453.
# At iteration 50 the loss is 9.538.
# At iteration 100 the loss is 9.176.
# At iteration 150 the loss is 14.331.
# At iteration 200 the loss is 13.921.
# At iteration 250 the loss is 20.676.
# At iteration 300 the loss is 14.429.
# At iteration 350 the loss is 9.765.
# At iteration 400 the loss is 14.081.
# At iteration 450 the loss is 16.898.
# At iteration 500 the loss is 22.803.
# At iteration 550 the loss is 11.712.
# At iteration 600 the loss is 17.302.
# At iteration 650 the loss is 14.826.
# At iteration 700 the loss is 19.490.
# At iteration 750 the loss is 20.877.
# At iteration 800 the loss is 9.499.
# At iteration 850 the loss is 25.553.
# At iteration 900 the loss is 19.828.
# Epoch: 14, time taken: 28.1s, validation accuracy: 0.821, recall: 0.44747766852378845, precision: 0.49987825751304626.
# At iteration 50 the loss is 8.852.
# At iteration 100 the loss is 11.975.
# At iteration 150 the loss is 14.459.
# At iteration 200 the loss is 19.896.
# At iteration 250 the loss is 14.725.
# At iteration 300 the loss is 11.860.
# At iteration 350 the loss is 17.341.
# At iteration 400 the loss is 14.461.
# At iteration 450 the loss is 14.727.
# At iteration 500 the loss is 11.772.
# At iteration 550 the loss is 17.374.
# At iteration 600 the loss is 25.965.
# At iteration 650 the loss is 19.358.
# At iteration 700 the loss is 19.900.
# At iteration 750 the loss is 12.391.
# At iteration 800 the loss is 17.448.
# At iteration 850 the loss is 17.451.
# At iteration 900 the loss is 6.509.
# Epoch: 15, time taken: 29.0s, validation accuracy: 0.817, recall: 0.42886948585510254, precision: 0.5047412514686584.
# At iteration 50 the loss is 11.298.
# At iteration 100 the loss is 8.960.
# At iteration 150 the loss is 12.008.
# At iteration 200 the loss is 14.717.
# At iteration 250 the loss is 20.300.
# At iteration 300 the loss is 17.287.
# At iteration 350 the loss is 16.895.
# At iteration 400 the loss is 11.568.
# At iteration 450 the loss is 17.296.
# At iteration 500 the loss is 16.732.
# At iteration 550 the loss is 11.702.
# At iteration 600 the loss is 17.366.
# At iteration 650 the loss is 14.427.
# At iteration 700 the loss is 14.319.
# At iteration 750 the loss is 18.013.
# At iteration 800 the loss is 16.801.
# At iteration 850 the loss is 14.036.
# At iteration 900 the loss is 20.983.
# Epoch: 16, time taken: 28.4s, validation accuracy: 0.817, recall: 0.4204030930995941, precision: 0.5088748335838318.
# At iteration 50 the loss is 12.256.
# At iteration 100 the loss is 8.848.
# At iteration 150 the loss is 31.838.
# At iteration 200 the loss is 11.591.
# At iteration 250 the loss is 6.161.
# At iteration 300 the loss is 11.854.
# At iteration 350 the loss is 22.986.
# At iteration 400 the loss is 16.801.
# At iteration 450 the loss is 4.129.
# At iteration 500 the loss is 11.474.
# At iteration 550 the loss is 11.692.
# At iteration 600 the loss is 12.253.
# At iteration 650 the loss is 14.025.
# At iteration 700 the loss is 9.488.
# At iteration 750 the loss is 22.616.
# At iteration 800 the loss is 8.848.
# At iteration 850 the loss is 28.988.
# At iteration 900 the loss is 20.107.
# Epoch: 17, time taken: 28.0s, validation accuracy: 0.815, recall: 0.46097156405448914, precision: 0.4949675500392914.
# At iteration 50 the loss is 14.272.
# At iteration 100 the loss is 11.699.
# At iteration 150 the loss is 12.098.
# At iteration 200 the loss is 9.143.
# At iteration 250 the loss is 17.341.
# At iteration 300 the loss is 4.127.
# At iteration 350 the loss is 14.724.
# At iteration 400 the loss is 19.733.
# At iteration 450 the loss is 9.064.
# At iteration 500 the loss is 26.079.
# At iteration 550 the loss is 13.913.
# At iteration 600 the loss is 22.987.
# At iteration 650 the loss is 22.777.
# At iteration 700 the loss is 11.396.
# At iteration 750 the loss is 14.053.
# At iteration 800 the loss is 17.163.
# At iteration 850 the loss is 11.397.
# At iteration 900 the loss is 17.278.
# Epoch: 18, time taken: 29.3s, validation accuracy: 0.823, recall: 0.39827558398246765, precision: 0.5252224802970886.
# At iteration 50 the loss is 14.426.
# At iteration 100 the loss is 11.643.
# At iteration 150 the loss is 23.350.
# At iteration 200 the loss is 23.017.
# At iteration 250 the loss is 19.317.
# At iteration 300 the loss is 20.204.
# At iteration 350 the loss is 17.120.
# At iteration 400 the loss is 11.562.
# At iteration 450 the loss is 25.765.
# At iteration 500 the loss is 22.629.
# At iteration 550 the loss is 14.057.
# At iteration 600 the loss is 22.777.
# At iteration 650 the loss is 31.782.
# At iteration 700 the loss is 11.864.
# At iteration 750 the loss is 17.448.
# At iteration 800 the loss is 14.874.
# At iteration 850 the loss is 11.701.
# At iteration 900 the loss is 11.560.
# Epoch: 19, time taken: 28.7s, validation accuracy: 0.828, recall: 0.44404444098472595, precision: 0.5133473873138428.
# At iteration 50 the loss is 22.988.
# At iteration 100 the loss is 28.810.
# At iteration 150 the loss is 14.192.
# At iteration 200 the loss is 14.826.
# At iteration 250 the loss is 17.085.
# At iteration 300 the loss is 19.920.
# At iteration 350 the loss is 22.937.
# At iteration 400 the loss is 25.873.
# At iteration 450 the loss is 17.162.
# At iteration 500 the loss is 16.778.
# At iteration 550 the loss is 17.066.
# At iteration 600 the loss is 14.024.
# At iteration 650 the loss is 22.606.
# At iteration 700 the loss is 8.741.
# At iteration 750 the loss is 8.742.
# At iteration 800 the loss is 11.717.
# At iteration 850 the loss is 17.604.
# At iteration 900 the loss is 6.582.
# Epoch: 20, time taken: 29.4s, validation accuracy: 0.829, recall: 0.4144786298274994, precision: 0.5242117643356323.
# At iteration 50 the loss is 19.731.
# At iteration 100 the loss is 11.843.
# At iteration 150 the loss is 22.907.
# At iteration 200 the loss is 19.732.
# At iteration 250 the loss is 16.650.
# At iteration 300 the loss is 25.400.
# At iteration 350 the loss is 22.753.
# At iteration 400 the loss is 11.561.
# At iteration 450 the loss is 14.318.
# At iteration 500 the loss is 22.608.
# At iteration 550 the loss is 14.319.
# At iteration 600 the loss is 6.443.
# At iteration 650 the loss is 23.476.
# At iteration 700 the loss is 14.131.
# At iteration 750 the loss is 14.825.
# At iteration 800 the loss is 16.496.
# At iteration 850 the loss is 11.428.
# At iteration 900 the loss is 14.825.
# Epoch: 21, time taken: 27.8s, validation accuracy: 0.824, recall: 0.4549730718135834, precision: 0.5023667216300964.
# At iteration 50 the loss is 14.979.
# At iteration 100 the loss is 9.793.
# At iteration 150 the loss is 22.419.
# At iteration 200 the loss is 14.730.
# At iteration 250 the loss is 11.326.
# At iteration 300 the loss is 19.545.
# At iteration 350 the loss is 23.391.
# At iteration 400 the loss is 9.172.
# At iteration 450 the loss is 17.338.
# At iteration 500 the loss is 19.729.
# At iteration 550 the loss is 14.726.
# At iteration 600 the loss is 17.119.
# At iteration 650 the loss is 9.068.
# At iteration 700 the loss is 4.982.
# At iteration 750 the loss is 19.913.
# At iteration 800 the loss is 14.425.
# At iteration 850 the loss is 11.709.
# At iteration 900 the loss is 17.179.
# Epoch: 22, time taken: 28.3s, validation accuracy: 0.824, recall: 0.4437551200389862, precision: 0.5056919455528259.
# At iteration 50 the loss is 9.060.
# At iteration 100 the loss is 25.965.
# At iteration 150 the loss is 12.106.
# At iteration 200 the loss is 19.704.
# At iteration 250 the loss is 8.848.
# At iteration 300 the loss is 19.706.
# At iteration 350 the loss is 11.845.
# At iteration 400 the loss is 7.032.
# At iteration 450 the loss is 14.172.
# At iteration 500 the loss is 19.149.
# At iteration 550 the loss is 28.972.
# At iteration 600 the loss is 20.093.
# At iteration 650 the loss is 12.233.
# At iteration 700 the loss is 17.367.
# At iteration 750 the loss is 14.978.
# At iteration 800 the loss is 15.167.
# At iteration 850 the loss is 17.051.
# At iteration 900 the loss is 28.639.
# Epoch: 23, time taken: 28.9s, validation accuracy: 0.815, recall: 0.4682643711566925, precision: 0.49507346749305725.
# At iteration 50 the loss is 2.043.
# At iteration 100 the loss is 12.516.
# At iteration 150 the loss is 16.809.
# At iteration 200 the loss is 14.048.
# At iteration 250 the loss is 13.766.
# At iteration 300 the loss is 11.839.
# At iteration 350 the loss is 17.123.
# At iteration 400 the loss is 22.937.
# At iteration 450 the loss is 6.589.
# At iteration 500 the loss is 22.226.
# At iteration 550 the loss is 14.980.
# At iteration 600 the loss is 14.866.
# At iteration 650 the loss is 11.749.
# At iteration 700 the loss is 14.735.
# At iteration 750 the loss is 11.688.
# At iteration 800 the loss is 22.976.
# At iteration 850 the loss is 17.119.
# At iteration 900 the loss is 14.914.
# Epoch: 24, time taken: 29.0s, validation accuracy: 0.828, recall: 0.43195292353630066, precision: 0.5093756318092346.
# At iteration 50 the loss is 22.615.
# At iteration 100 the loss is 11.688.
# At iteration 150 the loss is 14.173.
# At iteration 200 the loss is 9.487.
# At iteration 250 the loss is 11.839.
# At iteration 300 the loss is 22.895.
# At iteration 350 the loss is 17.551.
# At iteration 400 the loss is 14.459.
# At iteration 450 the loss is 12.189.
# At iteration 500 the loss is 14.113.
# At iteration 550 the loss is 12.106.
# At iteration 600 the loss is 22.604.
# At iteration 650 the loss is 17.204.
# At iteration 700 the loss is 12.626.
# At iteration 750 the loss is 22.937.
# At iteration 800 the loss is 19.709.
# At iteration 850 the loss is 14.723.
# At iteration 900 the loss is 9.487.
# Epoch: 25, time taken: 28.7s, validation accuracy: 0.830, recall: 0.4439411163330078, precision: 0.5057575106620789.
# At iteration 50 the loss is 17.447.
# At iteration 100 the loss is 19.790.
# At iteration 150 the loss is 17.680.
# At iteration 200 the loss is 9.172.
# At iteration 250 the loss is 11.557.
# At iteration 300 the loss is 15.128.
# At iteration 350 the loss is 14.868.
# At iteration 400 the loss is 6.246.
# At iteration 450 the loss is 17.205.
# At iteration 500 the loss is 14.026.
# At iteration 550 the loss is 11.142.
# At iteration 600 the loss is 14.668.
# At iteration 650 the loss is 17.129.
# At iteration 700 the loss is 14.173.
# At iteration 750 the loss is 9.346.
# At iteration 800 the loss is 17.285.
# At iteration 850 the loss is 19.922.
# At iteration 900 the loss is 20.198.
# Epoch: 26, time taken: 28.3s, validation accuracy: 0.833, recall: 0.4445754587650299, precision: 0.5108078122138977.
# At iteration 50 the loss is 17.163.
# At iteration 100 the loss is 22.864.
# At iteration 150 the loss is 11.427.
# At iteration 200 the loss is 17.356.
# At iteration 250 the loss is 11.700.
# At iteration 300 the loss is 25.770.
# At iteration 350 the loss is 11.393.
# At iteration 400 the loss is 19.812.
# At iteration 450 the loss is 11.014.
# At iteration 500 the loss is 17.166.
# At iteration 550 the loss is 19.729.
# At iteration 600 the loss is 14.271.
# At iteration 650 the loss is 17.285.
# At iteration 700 the loss is 20.043.
# At iteration 750 the loss is 19.922.
# At iteration 800 the loss is 1.979.
# At iteration 850 the loss is 11.427.
# At iteration 900 the loss is 16.979.
# Epoch: 27, time taken: 28.7s, validation accuracy: 0.828, recall: 0.3968949317932129, precision: 0.5230626463890076.
# At iteration 50 the loss is 17.124.
# At iteration 100 the loss is 22.407.
# At iteration 150 the loss is 17.511.
# At iteration 200 the loss is 16.786.
# At iteration 250 the loss is 14.468.
# At iteration 300 the loss is 9.150.
# At iteration 350 the loss is 22.581.
# At iteration 400 the loss is 16.983.
# At iteration 450 the loss is 14.186.
# At iteration 500 the loss is 17.059.
# At iteration 550 the loss is 19.913.
# At iteration 600 the loss is 11.700.
# At iteration 650 the loss is 17.445.
# At iteration 700 the loss is 11.561.
# At iteration 750 the loss is 14.282.
# At iteration 800 the loss is 17.150.
# At iteration 850 the loss is 9.316.
# At iteration 900 the loss is 11.560.
# Epoch: 28, time taken: 28.9s, validation accuracy: 0.829, recall: 0.4482637345790863, precision: 0.5072062611579895.
# At iteration 50 the loss is 12.108.
# At iteration 100 the loss is 19.526.
# At iteration 150 the loss is 16.889.
# At iteration 200 the loss is 14.049.
# At iteration 250 the loss is 13.910.
# At iteration 300 the loss is 16.950.
# At iteration 350 the loss is 19.529.
# At iteration 400 the loss is 12.109.
# At iteration 450 the loss is 16.982.
# At iteration 500 the loss is 23.078.
# At iteration 550 the loss is 17.321.
# At iteration 600 the loss is 9.507.
# At iteration 650 the loss is 17.297.
# At iteration 700 the loss is 14.425.
# At iteration 750 the loss is 4.847.
# At iteration 800 the loss is 9.129.
# At iteration 850 the loss is 17.285.
# At iteration 900 the loss is 4.128.
# Epoch: 29, time taken: 28.9s, validation accuracy: 0.826, recall: 0.4405613839626312, precision: 0.5044512748718262.
# At iteration 50 the loss is 11.936.
# At iteration 100 the loss is 8.848.
# At iteration 150 the loss is 17.338.
# At iteration 200 the loss is 14.576.
# At iteration 250 the loss is 9.486.
# At iteration 300 the loss is 9.061.
# At iteration 350 the loss is 17.048.
# At iteration 400 the loss is 6.779.
# At iteration 450 the loss is 14.460.
# At iteration 500 the loss is 20.763.
# At iteration 550 the loss is 8.742.
# At iteration 600 the loss is 16.494.
# At iteration 650 the loss is 19.552.
# At iteration 700 the loss is 11.687.
# At iteration 750 the loss is 11.936.
# At iteration 800 the loss is 16.953.
# At iteration 850 the loss is 14.270.
# At iteration 900 the loss is 11.559.
# Epoch: 30, time taken: 28.6s, validation accuracy: 0.825, recall: 0.4681847095489502, precision: 0.49880197644233704.
# The estimated test accuracy is 0.813, recall 0.5879971385002136, precision 0.6852739453315735.

# %%
plt.plot(range(1, EPOCHS+1), recalls)

# %%
plt.plot(range(1, EPOCHS+1), precisions)
